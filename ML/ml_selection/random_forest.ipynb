# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
import numpy as np
import pre_data as eda

data = pd.read_csv(
        './data/train.csv',
        encoding='cp949',
)
# 상위 디렉토리를 경로에 추가 (test.ipynb 파일 기준으로)
preprocessed_data = eda.preprocessing(data)

# 1. 데이터 전처리 (범주형 데이터 변환 및 스케일링)
object_columns = preprocessed_data.select_dtypes(include=['object'])
convert_data, _ = eda.convert_category_into_integer(preprocessed_data, object_columns)

# 타겟 변수 및 독립 변수 설정
X = convert_data.drop('Churn', axis=1)
y = convert_data['Churn'].astype(int)

# 데이터 스케일링
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# X: 피처 데이터셋, y: 타겟(종속 변수) 데이터셋
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 인덱스 재설정 (reset_index)
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# RandomForestClassifier 모델을 사용한 후진제거
def backward_elimination_random_forest(X_train, X_test, y_train, y_test, significance_level=0.05):
    model = RandomForestClassifier(random_state=42)  # RandomForest 모델 선언

    while True:
        # 모델 학습
        model.fit(X_train, y_train)

        # 모델 평가
        y_pred_class = model.predict(X_test)

        accuracy = accuracy_score(y_test, y_pred_class)
        precision = precision_score(y_test, y_pred_class)
        recall = recall_score(y_test, y_pred_class)
        f1 = f1_score(y_test, y_pred_class)

        # 중간 결과 출력
        print(f"\nAfter removing feature(s), Current Model Performance:")
        print(f"Accuracy: {accuracy}")
        print(f"Precision: {precision}")
        print(f"Recall: {recall}")
        print(f"F1 Score: {f1}")

        # 변수 중요도 확인
        importances = model.feature_importances_
        min_importance = np.min(importances)

        # 가장 낮은 중요도를 가진 변수 제거
        if min_importance < significance_level:
            worst_feature_index = np.argmin(importances)
            worst_feature = X_train.columns[worst_feature_index]

            print(f"Removing '{worst_feature}' with importance {importances[worst_feature_index]}")
            X_train = X_train.drop(columns=[worst_feature])
            X_test = X_test.drop(columns=[worst_feature])
        else:
            break  # 모든 변수의 중요도가 유의미한 경우 루프 종료

    return X_train, X_test, model

# 후진제거 실행
X_train_reduced, X_test_reduced, final_model = backward_elimination_random_forest(X_train, X_test, y_train, y_test)

# 최종 모델 학습 및 평가
y_pred_class = final_model.predict(X_test_reduced)

# 최종 성능 평가
accuracy = accuracy_score(y_test, y_pred_class)
precision = precision_score(y_test, y_pred_class)
recall = recall_score(y_test, y_pred_class)
f1 = f1_score(y_test, y_pred_class)

# 최종 평가 결과 출력
print("\nFinal Model Performance:")
print(f"Final Model Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# nan-value filled
# MonthlyRevenue : 50887, 삭제된 수 : 1
# MonthlyMinutes : 50883, 삭제된 수 : 4
# TotalRecurringCharge : 50874, 삭제된 수 : 9
# DirectorAssistedCalls : 50874, 삭제된 수 : 0
# OverageMinutes : 50870, 삭제된 수 : 4
# RoamingCalls : 50862, 삭제된 수 : 8
# PercChangeMinutes : 50860, 삭제된 수 : 2
# DroppedCalls : 50856, 삭제된 수 : 4
# BlockedCalls : 50852, 삭제된 수 : 4
# UnansweredCalls : 50842, 삭제된 수 : 10
# CustomerCareCalls : 50840, 삭제된 수 : 2
# ThreewayCalls : 50836, 삭제된 수 : 4
# ReceivedCalls : 50830, 삭제된 수 : 6
# OutboundCalls : 50827, 삭제된 수 : 3
# InboundCalls : 50823, 삭제된 수 : 4
# PeakCallsInOut : 50821, 삭제된 수 : 2
# OffPeakCallsInOut : 50806, 삭제된 수 : 15
# DroppedBlockedCalls : 50792, 삭제된 수 : 14
# CallForwardingCalls : 50779, 삭제된 수 : 13
# CallWaitingCalls : 50779, 삭제된 수 : 0
# MonthsInService : 50778, 삭제된 수 : 1
# UniqueSubs : 50777, 삭제된 수 : 1
# ActiveSubs : 50777, 삭제된 수 : 0
# Handsets : 50773, 삭제된 수 : 4
# HandsetModels : 50773, 삭제된 수 : 0
# CurrentEquipmentDays : 50768, 삭제된 수 : 5
# RetentionCalls : 50634, 삭제된 수 : 134
# RetentionOffersAccepted : 50634, 삭제된 수 : 0
# ReferralsMadeBySubscriber : 50623, 삭제된 수 : 11
# AdjustmentsToCreditRating : 50621, 삭제된 수 : 2
# 최종 데이터 크기 : 50621
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7198024691358025
# Precision: 0.583743842364532
# Recall: 0.08158347676419965
# F1 Score: 0.14315916641498036
# Removing 'CallForwardingCalls' with importance 0.0005179472250755613
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7177283950617284
# Precision: 0.5569007263922519
# Recall: 0.07917383820998279
# F1 Score: 0.13863773357444242
# Removing 'RetentionOffersAccepted' with importance 0.0008564827732721384
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.718716049382716
# Precision: 0.5676959619952494
# Recall: 0.08227194492254733
# F1 Score: 0.14371617558628982
# Removing 'OwnsMotorcycle' with importance 0.0012845305939299914
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7176296296296296
# Precision: 0.5552884615384616
# Recall: 0.07951807228915662
# F1 Score: 0.13911472448057813
# Removing 'OptOutMailings' with importance 0.001367269693425626
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.719604938271605
# Precision: 0.5812807881773399
# Recall: 0.08123924268502582
# F1 Score: 0.14255511929930534
# Removing 'AdjustmentsToCreditRating' with importance 0.002168108817172807
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7189135802469135
# Precision: 0.5628997867803838
# Recall: 0.09087779690189329
# F1 Score: 0.15649081209247184
# Removing 'NonUSTravel' with importance 0.0024802100299202885
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.719604938271605
# Precision: 0.5726872246696035
# Recall: 0.08950086058519793
# F1 Score: 0.15480797856504913
# Removing 'RetentionCalls' with importance 0.002658922224050659
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7184197530864197
# Precision: 0.56
# Recall: 0.08674698795180723
# F1 Score: 0.15022354694485843
# Removing 'ReferralsMadeBySubscriber' with importance 0.0030669011999497997
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7206913580246913
# Precision: 0.5936739659367397
# Recall: 0.08399311531841652
# F1 Score: 0.1471652593486128
# Removing 'RVOwner' with importance 0.0032579731828411484
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7177283950617284
# Precision: 0.5601023017902813
# Recall: 0.07538726333907057
# F1 Score: 0.1328883495145631
# Removing 'HasCreditCard' with importance 0.004245195690075665
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7194074074074074
# Precision: 0.5816326530612245
# Recall: 0.07848537005163511
# F1 Score: 0.13830755232029118
# Removing 'BuysViaMailOrder' with importance 0.004215336685820964
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7190123456790124
# Precision: 0.5746268656716418
# Recall: 0.07951807228915662
# F1 Score: 0.13970365890535227
# Removing 'Homeownership' with importance 0.004425705374976731
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7186172839506173
# Precision: 0.5740740740740741
# Recall: 0.0746987951807229
# F1 Score: 0.13219616204690832
# Removing 'HandsetWebCapable' with importance 0.004414169018207771
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7190123456790124
# Precision: 0.5704225352112676
# Recall: 0.08364888123924269
# F1 Score: 0.14590213149204442
# Removing 'MadeCallToRetentionTeam' with importance 0.0045694999560670505
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7199012345679012
# Precision: 0.5886889460154242
# Recall: 0.07882960413080894
# F1 Score: 0.13904068002428657
# Removing 'OwnsComputer' with importance 0.004531307786615426
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7182222222222222
# Precision: 0.5634146341463414
# Recall: 0.07951807228915662
# F1 Score: 0.13936651583710408
# Removing 'TruckOwner' with importance 0.004861329704921363
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7182222222222222
# Precision: 0.5588235294117647
# Recall: 0.08502581755593804
# F1 Score: 0.14759486106961459
# Removing 'NotNewCellphoneUser' with importance 0.005020363706054432
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7207901234567902
# Precision: 0.5924170616113744
# Recall: 0.08605851979345955
# F1 Score: 0.15028554253080853
# Removing 'ChildrenInHH' with importance 0.005116804258131937
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7210864197530864
# Precision: 0.5918367346938775
# Recall: 0.08984509466437177
# F1 Score: 0.15600717274357442
# Removing 'HandsetRefurbished' with importance 0.005305550373435436
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.718320987654321
# Precision: 0.5590200445434298
# Recall: 0.0864027538726334
# F1 Score: 0.14967203339296362
# Removing 'RespondsToMailOffers' with importance 0.005155587048187916
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.719604938271605
# Precision: 0.5726872246696035
# Recall: 0.08950086058519793
# F1 Score: 0.15480797856504913
# Removing 'NewCellphoneUser' with importance 0.005534396630821755
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7160493827160493
# Precision: 0.5357142857142857
# Recall: 0.0774526678141136
# F1 Score: 0.13533834586466165
# Removing 'ActiveSubs' with importance 0.008130534911432787
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7212839506172839
# Precision: 0.5962877030162413
# Recall: 0.08846815834767642
# F1 Score: 0.15407673860911272
# Removing 'HandsetModels' with importance 0.008355913301752086
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7186172839506173
# Precision: 0.5660377358490566
# Recall: 0.08261617900172118
# F1 Score: 0.14418744367677983
# Removing 'MaritalStatus' with importance 0.010073998815069507
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7206913580246913
# Precision: 0.5905882352941176
# Recall: 0.0864027538726334
# F1 Score: 0.15075075075075076
# Removing 'Handsets' with importance 0.010671289165593813
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7188148148148148
# Precision: 0.5653153153153153
# Recall: 0.0864027538726334
# F1 Score: 0.14989549119140042
# Removing 'ThreewayCalls' with importance 0.011268747015869293
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7202962962962963
# Precision: 0.5798687089715536
# Recall: 0.09122203098106713
# F1 Score: 0.15764425936942297
# Removing 'Occupation' with importance 0.011936094063519772
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7182222222222222
# Precision: 0.5530612244897959
# Recall: 0.09328743545611015
# F1 Score: 0.15964653902798231
# Removing 'UniqueSubs' with importance 0.013747482210950679
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7192098765432099
# Precision: 0.5643153526970954
# Recall: 0.093631669535284
# F1 Score: 0.16061411278417478
# Removing 'PrizmCode' with importance 0.014182872722100705
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7220740740740741
# Precision: 0.5938144329896907
# Recall: 0.09913941480206541
# F1 Score: 0.16991150442477876
# Removing 'HandsetPrice' with importance 0.01591758259992273
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7188148148148148
# Precision: 0.5577689243027888
# Recall: 0.0963855421686747
# F1 Score: 0.16436747872028176
# Removing 'CallWaitingCalls' with importance 0.019592713030727127
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7180246913580247
# Precision: 0.5475285171102662
# Recall: 0.09913941480206541
# F1 Score: 0.16788108423200232
# Removing 'CreditRating' with importance 0.021642484457697474
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7193086419753086
# Precision: 0.5636363636363636
# Recall: 0.09604130808950086
# F1 Score: 0.16411764705882353
# Removing 'CustomerCareCalls' with importance 0.022319990796381643
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7165432098765432
# Precision: 0.5360824742268041
# Recall: 0.08950086058519793
# F1 Score: 0.15339233038348082
# Removing 'RoamingCalls' with importance 0.02359497869755548
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.717925925925926
# Precision: 0.5481335952848723
# Recall: 0.09604130808950086
# F1 Score: 0.1634446397188049
# Removing 'DirectorAssistedCalls' with importance 0.026292561408906526
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7188148148148148
# Precision: 0.5591836734693878
# Recall: 0.09432013769363166
# F1 Score: 0.1614138438880707
# Removing 'AgeHH2' with importance 0.0275670030037896
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7188148148148148
# Precision: 0.556420233463035
# Recall: 0.09845094664371773
# F1 Score: 0.16730038022813687
# Removing 'IncomeGroup' with importance 0.029274447770436765
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7186172839506173
# Precision: 0.5482758620689655
# Recall: 0.10946643717728055
# F1 Score: 0.1824964131994261
# Removing 'BlockedCalls' with importance 0.03502379981196477
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7178271604938271
# Precision: 0.5425531914893617
# Recall: 0.10533562822719449
# F1 Score: 0.176419717497838
# Removing 'OverageMinutes' with importance 0.037767053667217054
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7181234567901235
# Precision: 0.5451327433628319
# Recall: 0.10602409638554217
# F1 Score: 0.17752161383285303
# Removing 'InboundCalls' with importance 0.039999829549003024
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7199012345679012
# Precision: 0.5564648117839607
# Recall: 0.11703958691910499
# F1 Score: 0.19340159271899887
# Removing 'DroppedCalls' with importance 0.044856708703275
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7214814814814815
# Precision: 0.5746924428822495
# Recall: 0.11256454388984509
# F1 Score: 0.18825561312607944
# Removing 'AgeHH1' with importance 0.047812359532444185
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7191111111111111
# Precision: 0.5504132231404959
# Recall: 0.11462994836488813
# F1 Score: 0.18974358974358974
# Removing 'TotalRecurringCharge' with importance 0.049794465499526284
#
# After removing feature(s), Current Model Performance:
# Accuracy: 0.7148641975308642
# Precision: 0.5152542372881356
# Recall: 0.10464716006884682
# F1 Score: 0.17396280400572245
#
# Final Model Performance:
# Final Model Accuracy: 0.7148641975308642
# Precision: 0.5152542372881356
# Recall: 0.10464716006884682
# F1 Score: 0.17396280400572245
